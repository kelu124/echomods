# %%
import bibtexparser
import os.path

INVIS = "[](@autogenerated - invisible comment)"
with open('all.bib') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

#print(bib_database.entries)
# Out:
# Entry type patent not standard. Not considered.

# %%
print(bib_database.comments)
print(bib_database.preambles)
print(bib_database.strings)
# Out:
# []
# []
# OrderedDict()

# %% [markdown]
# # DOIs but no PDF found

# %%
AllRefs = ""
for k in bib_database.entries:
    #print k.keys()
    m = "* "
    if os.path.isfile("ArticlesPDF/"+k["ID"]+".pdf"):
        m += "[x] "
    else:
        m += "[ ] "
    m += "["+k["ID"]+"] __"+k["title"]+"__"
    if "author" in k.keys():
        m += " by "+k["author"]
   
    if "doi" in k.keys():
        m += ". (_DOI: ["+k["doi"]+"](https://doi.org/"+k["doi"]+")_)."
        if not os.path.isfile("ArticlesPDF/"+k["ID"]+".pdf"):
            print(m.replace("{","").replace("}",""))
    AllRefs += m+"\n"
# Out:
# * [ ] [park_implementation_2018] __Implementation of a backend system for real-time intravascular ultrasound imaging__ by Park, Jun-Won and Moon, Ju-Young and Lee, Junsu and Chang, Jin Ho. (_DOI: [10.7776/ASK2018.37.4.215](https://doi.org/10.7776/ASK2018.37.4.215)_).
# * [ ] [raj_embedded_2014] __An embedded system for elasticity measurement using ultrasound waves__ by Raj, Jean and Smk, Rahman and Anand, Sneh. (_DOI: [10.13140/RG.2.1.2175.0165](https://doi.org/10.13140/RG.2.1.2175.0165)_).
# * [ ] [csany_real-time_2019] __A real-time data-based scan conversion method for single element ultrasound transducers__ by Csány, Gergely and Szalai, Klára and Gyöngy, Miklós. (_DOI: [10.1016/j.ultras.2018.10.006](https://doi.org/10.1016/j.ultras.2018.10.006)_).
# * [ ] [escrig_clean--place_2019] __Clean-in-place monitoring of different food fouling materials using ultrasonic measurements__ by Escrig, J. and Woolley, E. and Rangappa, S. and Simeone, A. and Watson, N. J.. (_DOI: [10.1016/j.foodcont.2019.05.013](https://doi.org/10.1016/j.foodcont.2019.05.013)_).
# * [ ] [jurkonis_mapping_2019] __Mapping Microbubble and Ultrasound Spatio-temporal Interaction by M-mode Imaging: The Study of Feasibility__ by Jurkonis, R. and Sakalauskas, A. and Lukoševičius, A. and Maciulevičius, M. and Tamošiūnas, M. and Šatkauskas, S.. (_DOI: [10.1134/S1063771019020040](https://doi.org/10.1134/S1063771019020040)_).
# * [ ] [massari_mechatronic_2019] __A Mechatronic Platform for Computer Aided Detection of Nodules in Anatomopathological Analyses via Stiffness and Ultrasound Measurements__ by Massari, Luca and Bulletti, Andrea and Prasanna, Sahana and Mazzoni, Marina and Frosini, Francesco and Vicari, Elena and Pantano, Marcello and Staderini, Fabio and Ciuti, Gastone and Cianchi, Fabio and Messerini, Luca and Capineri, Lorenzo and Menciassi, Arianna and Oddo, Calogero Maria. (_DOI: [10.3390/s19112512](https://doi.org/10.3390/s19112512)_).
# * [ ] [bazan_improved_2019] __Improved Spectral Method to Obtain Strains of an Ex-Vivo Membrane Tissue and Its Performance Under Elevated SNRs__ by Bazán, Ivonne and Ramos, Antonio and Negreira, Carlos. (_DOI: [10.1007/978-3-030-31635-8_184](https://doi.org/10.1007/978-3-030-31635-8_184)_).
# * [ ] [kim_new_2019] __A new frequency domain passive acoustic mapping method using passive Hilbert beamforming to reduce the computational complexity of fast Fourier transform__ by Kim, Pilsu and Hee Song, Jae and Song, Tai-Kyong. (_DOI: [10.1016/j.ultras.2019.106030](https://doi.org/10.1016/j.ultras.2019.106030)_).
# * [ ] [gibney_open-hardware_2016] __‘Open-hardware’ pioneers push for low-cost lab kit__ by Gibney, Elizabeth. (_DOI: [10.1038/531147a](https://doi.org/10.1038/531147a)_).
# * [ ] [shi_monolithic_2018] __Monolithic Integration of Micron-scale Piezoelectric Materials with CMOS for Biomedical Applications__ by Shi, C. and Costa, T. and Elloian, J. and Shepard, K. L.. (_DOI: [10.1109/IEDM.2018.8614632](https://doi.org/10.1109/IEDM.2018.8614632)_).
# * [ ] [ramos_dependence_2000] __Dependence of pulser driving responses on electrical and motional characteristics of NDE ultrasonic probes__ by Ramos, A. and San Emeterio, J. L. and Sanz, P. T.. (_DOI: [10.1016/S0041-624X(99)00072-4](https://doi.org/10.1016/S0041-624X(99)00072-4)_).
# * [ ] [nikitin_ultrasonic_2017] __Ultrasonic system and easy ILI tools for pipeline and tubular inspection__ by Nikitin, Konstantin. (_DOI: [10.13140/RG.2.2.25093.45288](https://doi.org/10.13140/RG.2.2.25093.45288)_).
# * [ ] [jager_ultrasonic_2017] __Ultrasonic phased array for sound drift compensation in gas flow metering__ by Jäger, A. and Unger, A. and Wang, H. and Arnaudov, Y. and Kang, L. and Su, R. and Lines, D. and Ramadas, S. N. and Dixon, S. and Kupnik, M.. (_DOI: [10.1109/ULTSYM.2017.8092174](https://doi.org/10.1109/ULTSYM.2017.8092174)_).
# * [ ] [cortela_evaluation_2015] __Evaluation of acoustic and thermal properties of gellan-gum phantom to mimic biological tissue__ by Cortela, G. and Lima, K. M. and Maggi, L. E. and Negreira, C. and Pereira, W. C.A.. (_DOI: [10.1109/PAHCE.2015.7173326](https://doi.org/10.1109/PAHCE.2015.7173326)_).
# * [ ] [clementi_innovative_2017] __Innovative Method to Authenticate Copper Canisters Used for Spent Nuclear Fuel Based on the Ultrasonic Investigation of the Friction Stir Weld__ by Clementi, Chiara and Capineri, Lorenzo and Littmann, Francois. (_DOI: [10.1109/ACCESS.2017.2694878](https://doi.org/10.1109/ACCESS.2017.2694878)_).
# * [ ] [ivanova_acoustic_2017] __Acoustic investigations of the steel samples deformation during the tensile__ by Ivanova, Yonka and Partalin, Todor and Pashkuleva, Desislava. (_DOI: [10.1134/S1061830917010077](https://doi.org/10.1134/S1061830917010077)_).
# * [ ] [mamou_high-frequency_2008] __High-frequency Pulse-compression Ultrasound Imaging with an Annular Array__ by Mamou, J. and Ketterling, J. A. and Silverman, R. H.. (_DOI: [10.1007/978-1-4020-8823-0_11](https://doi.org/10.1007/978-1-4020-8823-0_11)_).
# * [ ] [kjeken_systematic_2011] __Systematic review of design and effects of splints and exercise programs in hand osteoarthritis__ by Kjeken, Ingvild and Smedslund, Geir and Moe, Rikke H. and Slatkowsky-Christensen, Barbara and Uhlig, Till and Hagen, Kåre Birger. (_DOI: [10.1002/acr.20427](https://doi.org/10.1002/acr.20427)_).
# * [ ] [bonvoisin_openness_2017] __Openness assessment of 132 open source hardware products__ by Bonvoisin, Jérémy. (_DOI: [http://dx.doi.org/10.14279/depositonce-5977](https://doi.org/http://dx.doi.org/10.14279/depositonce-5977)_).
# * [ ] [bonvoisin_measuring_2018] __Measuring Openness in Open Source Hardware with the Open-o-Meter__ by Bonvoisin, Jérémy and Mies, Robert. (_DOI: [10.1016/j.procir.2018.08.306](https://doi.org/10.1016/j.procir.2018.08.306)_).
# * [ ] [shah_yosys+nextpnr:_2019] __Yosys+nextpnr: An Open Source Framework from Verilog to Bitstream for Commercial FPGAs__ by Shah, David and Hung, Eddie and Wolf, Clifford and Bazanski, Serge and Gisselquist, Dan and Milanovic, Miodrag. (_DOI: [10.1109/FCCM.2019.00010](https://doi.org/10.1109/FCCM.2019.00010)_).
# * [ ] [tiwari_efficient_2017] __Efficient FPGA-based FIR – architecture and its significance in ultrasonic signal processing__ by Tiwari, Kumar Anubhav and Ostreika, Armantas and Platuziene, Jurate. (_DOI: [10.21595/jve.2017.18932](https://doi.org/10.21595/jve.2017.18932)_).
# * [ ] [tortoli_contribution_2019] __The contribution of research platforms to the pathway from off-line to real-time high-frame-rate imaging__ by Tortoli, Piero and Boni, Enrico. (_DOI: [10.1121/1.5136923](https://doi.org/10.1121/1.5136923)_).
# * [ ] [njiki_multi-fpga_2019] __A multi-FPGA architecture-based real-time TFM ultrasound imaging__ by Njiki, Mickael and Elouardi, Abdelhafid and Bouaziz, Samir and Casula, Olivier and Roy, Olivier. (_DOI: [10.1007/s11554-016-0563-5](https://doi.org/10.1007/s11554-016-0563-5)_).
# * [ ] [jensen_performance_2010] __Performance of SARUS: A Synthetic Aperture Real-time Ultrasound System__ by Jensen, Jørgen Arendt and Holten-Lund, Hans and Nielson, Ronnie Thorup and Tomov, Borislav Gueorguiev and Stuart, Matthias Bo and Nikolov, Svetoslav Ivanov and Hansen, Martin and Larsen, Ulrik Darling. (_DOI: [10.1109/ULTSYM.2010.0075](https://doi.org/10.1109/ULTSYM.2010.0075)_).
# * [ ] [pearce_emerging_2017] __Emerging Business Models for Open Source Hardware__ by Pearce, Joshua M.. (_DOI: [10.5334/joh.4](https://doi.org/10.5334/joh.4)_).
# * [ ] [csany_low-cost_2017] __A low-cost portable ultrasound system for skin diagnosis__ by Csány, Gergely and Szalai, Klára and Füzesi, Krisztián and Gyöngy, Miklós. (_DOI: [10.1121/2.0000701](https://doi.org/10.1121/2.0000701)_).
# * [ ] [enwia_open-source_2019] __An Open-Source Ultrasound Imaging System with Wearable Active Probes__ by Enwia, George and Pashaei, Vida and Bayat, Mahdi and Roman, Alex and Mandal, Soumyajit. (_DOI: [10.1109/NAECON46414.2019.9058162](https://doi.org/10.1109/NAECON46414.2019.9058162)_).
# * [ ] [meng_rtl-ultrasound_2019] __rtl-ultrasound: Ultrasound imaging with RTL-SDR__ by Meng, William. (_DOI: [10.5281/zenodo.3571440](https://doi.org/10.5281/zenodo.3571440)_).
# * [ ] [moradi_detection_2006] __Detection of Prostate Cancer from RF Ultrasound Echo Signals Using Fractal Analysis__ by Moradi, Mehdi and Abolmaesumi, Purang and Isotalo, Phillip A. and Siemens, David R. and Sauerbrei, Eric E. and Mousavi, Parvin. (_DOI: [10.1109/IEMBS.2006.259325](https://doi.org/10.1109/IEMBS.2006.259325)_).
# * [ ] [schneider_fully_2010] __A Fully Programmable Computing Architecture for Medical Ultrasound Machines__ by Schneider, Fabio Kurt and Agarwal, Anup and Yoo, Yang Mo and Fukuoka, Tetsuya and Kim, Yongmin. (_DOI: [10.1109/TITB.2009.2025653](https://doi.org/10.1109/TITB.2009.2025653)_).
# * [ ] [seviaryn_quantitative_2020] __Quantitative evaluation of skin using high-resolution ultrasound__ by Seviaryn, Fedar and Schreiner, Gregory and Youssef, Sarah and Maeva, Anna and Malyarenko, Eugene and Seviaryna, Inna and Maev, Roman Gr. (_DOI: [10.1117/12.2549821](https://doi.org/10.1117/12.2549821)_).
# * [ ] [chen_wireless_2019] __Wireless Wearable Ultrasound Sensor on a Paper Substrate to Characterize Respiratory Behavior__ by Chen, Ang and Halton, Andrew Joshua and Rhoades, Rachel Diane and Booth, Jayden Charles and Shi, Xinhao and Bu, Xiangli and Wu, Ning and Chae, Junseok. (_DOI: [10.1021/acssensors.9b00043](https://doi.org/10.1021/acssensors.9b00043)_).

# %%
text_file = open("AllRefs.md", "w")
text_file.write(str(AllRefs).replace("{","").replace("}","")+"\n"+str(INVIS))
text_file.close()

# %% [markdown]
# ## With no DOI

# %%
AllRefs = ""
for k in bib_database.entries:
    #print k.keys()
    m = "* "
    if os.path.isfile("ArticlesPDF/"+k["ID"]+".pdf"):
        m += "[x] "
    else:
        m += "[ ] "
    m += "["+k["ID"]+"] __"+k["title"]+"__"
    if "author" in k.keys():
        m += " by "+k["author"]
   
    if "doi" not in k.keys():
        if not os.path.isfile("ArticlesPDF/"+k["ID"]+".pdf"):
            print(m.replace("{","").replace("}",""))
    AllRefs += m+"\n"
# Out:
# * [ ] [thomenius_instrumentation_2018] __INSTRUMENTATION DESIGN FOR ULTRASONIC IMAGING__ by Thomenius, Kai
# * [ ] [lecklider_ultrasound_2012] __Ultrasound imaging: more than skin-deep__ by Lecklider, Tom
# * [ ] [silverman_effect_1995] __The effect of transducer bandwidth on ultrasonic image characteristics__ by Silverman, R. H. and Vinarsky, E. and Woods, S. M. and Lizzi, F. L. and Coleman, D. J.
# * [ ] [ribas_logiciels_2016] __Logiciels \& objets libres: Animer une communauté autour d'un projet ouvert__ by Ribas, Stéphane and Ubeda, Stéphane and Guillaud, Patrick
# * [ ] [carlin_ultrasonics_1960] __Ultrasonics__ by Carlin, Benson
# * [ ] [joyner_ultrasound_1974] __Ultrasound in the diagnosis of cardiovascular-pulmonary disease__
# * [ ] [holm_abdominal_1976] __Abdominal ultrasound__
# * [ ] [kremkau_diagnostic_1989] __Diagnostic ultrasound: principles, instruments, and exercises__ by Kremkau, Frederick W.
# * [ ] [lunt_handbook_1978] __Handbook of ultrasonic B-scanning in medicine__ by Lunt, R.
# * [ ] [countries_future_1985] __Future use of new imaging technologies in developing countries : report of a WHO scientific group [meeting held in Geneva from 24 September to 1 October 1984]__ by Countries, WHO Scientific Group on the Future Use of New Imaging Technologies in Developing and Organization, World Health
# * [ ] [huijben_learning_2019] __Learning Sub-Sampling and Signal Recovery with Applications in Ultrasound Imaging__ by Huijben, Iris A. M. and Veeling, Bastiaan S. and Janse, Kees and Mischi, Massimo and van Sloun, Ruud J. G.
# * [ ] [nikolov_practical_2010] __Practical Applications of Synthetic Aperture Imaging__ by Nikolov, Svetoslav
# * [ ] [karlen_mobile_2015] __Mobile point-of-care monitors and diagnostic device design__
# * [ ] [buess_system_1984] __A system for a transanal endoscopic rectum operation__ by Buess, G. and Hutterer, F. and Theiss, J. and Böbel, M. and Isselhard, W. and Pichlmaier, H.
# * [ ] [lie_low_2008] __A low cost CPLD-based ultrasonic flowmeter__ by Lie, Ioan and Tiponuţ, Virgil and Bogdanov, Ivan and Ionel, Sabin
# * [ ] [hailu_prototype_2013] __Prototype Development of an A-Mode Ultrasound Based Intrafraction Motion Management System__ by Hailu, Abebe and Lundqvist, Fredrik
# * [ ] [martins_-scan_2017] __A-scan ultrassônico aplicado na identificação da camada adiposa__ by Martins, Yan Watanabe
# * [ ] [chesbrough_open_2003] __Open Innovation: The New Imperative for Creating and Profiting From Technology__ by Chesbrough, Henry
# * [ ] [chavez_open_1] __Open Source Technology for Medical Practice in Developing Countries__ by Chavez, Afton and Kovarik, Carrie and Chavez, Afton and Kovarik, Carrie
# * [ ] [szabo_diagnostic_2004] __Diagnostic ultrasound imaging: inside out__ by Szabo, Thomas L
# * [ ] [baldwin_modularity_2012] __Modularity and organizations__ by Baldwin, Carliss Y.
# * [ ] [tiwari_frugal_2017] __Frugal innovation in Germany: A qualitative analysis of potential socio-economic impacts__ by Tiwari, Rajnish and Fischer, Luise and Kalogerakis, Katharina
# * [ ] [de_maria_safe_2018] __Safe innovation: On medical device legislation in Europe and Africa__ by De Maria, Carmelo and Di Pietro, Licia and Lantada, Andrés Díaz and Madete, June and Makobore, Philippa Ngaju and Mridha, Mannan and Ravizza, Alice and Torop, Janno and Ahluwalia, Arti

# %% [markdown]
# # Devices review

# %%
devices = "sharmistha adl5511 AFE5809 AD8331 ad8332 NMT0572SC LM96511 AD9276 AD9273 LM96550 MAX668 MAX1856 MIC3172 HV9150 MAX15031 ADA4807 MAX14808 AD9276 AD9273 AFE5808 max2077 MAx2082  AFE5851 MAX4107 AD9272 ADC10D020 AD9276 VCA8500 AFE5809 AFE5808"
devices += " MAX1438 MAX2079 MAX2084 MAX14813 MAX4936 STHV748 AD9671 AD8334 max14866 MD2134 MD0101 MD0100 HV7360 HV7361 HV7321 AFE5809 LM96551 LM96530 LM96570 AD9276"
devices += " verasonics lecoeur" #Cortex-A9 Altera xilinx
devices += " MAX14808 TX810 AFE5851 LM96570 HV7350 LM96530 LM96570 AD8031 AD9214 ADS5517 SMA231 THS4509 LT3958 ADC10065 iCE40HX4K MD2131 AFE5805 AD9276 MD1210 TC6320"
devices = list(set(devices.replace("  "," ").lower().split(" ")))

# %%
import os,glob
result = {}
for dev in devices:
    result[dev] = []
folder_path = './ArticlesPDF/txt/'
for filename in glob.glob(os.path.join(folder_path, '*.txt')):
    with open(filename, 'r') as f:
        text = f.read().lower().replace("max-",'max').replace("ad-",'ad').replace("afe-",'afe').replace("hv-",'hv')
        text = text
        #print(filename)
        for dev in devices:
            if len(dev) and dev in text:
                result[dev].append(filename.split("/")[-1].split(".")[0])
print(result)
# Out:
# {'max2082': ['hewener_mobile_2019'], 'lm96551': ['shomaji_early_2019', 'hager_lightprobe:_2017', 'roman_open-source_2019', 'hager_design_2019', 'govindan_reconfigurable_2015', 'roman_open-source_2018'], 'adl5511': ['jonveaux_arduino-like_2017'], 'lm96511': ['yu_low-power_2012'], 'max15031': [], 'ads5517': ['weibao_qiu_programmable_2011', 'qiu_programmable_2011', 'qiu_programmable_2010', 'wang_development_2017'], 'afe5805': ['assef_flexible_2015', 'assef_design_2012', 'assef_compact_2014', 'assef_initial_2016'], 'vca8500': ['wang_high_2019', 'vasudevan_programmable_2014', 'govindan_reconfigurable_2015'], 'max14866': ['pashaei_flexible_2020'], 'md1210': ['sharma_development_2015', 'levesque_real-time_2009', 'luc_jonveaux_un0rick_2019', '2011_PhilippeL%C3%A9vesque', 'nguyen_estimating_2019', 'levesque_architecture_2011'], 'afe5851': ['gwirc_desarrollo_2019', 'hager_lightprobe:_2017', 'hager_design_2019', 'LP1', 'hager_lightprobe:_2019'], 'tx810': ['cheung_multi-channel_2012', 'batbayar_hardware_2018', 'wang_high_2019', 'hager_lightprobe:_2017', 'hager_design_2019', 'LP1', 'hager_lightprobe:_2019'], 'md0101': ['sharma_development_2015', 'lay_-vivo_2018', 'hager_design_2019', 'LP1', 'hager_lightprobe:_2019', 'lay_progress_2016'], 'max14813': [], 'hv9150': [], 'adc10065': ['luc_jonveaux_un0rick_2019'], 'sthv748': ['joseph_artsenstouch_2015'], 'ad8332': ['zhang_multi-channel_2017', 'levesque_real-time_2009', 'chang-hong_hu_design_2008', 'brunner_how_2002', '2011_PhilippeL%C3%A9vesque', 'nguyen_estimating_2019', 'levesque_architecture_2011'], 'ad8331': ['lorenzo_experimental_2009', 'pandey_open_2019', 'qiu_high-resolution_2020', 'qiu_delayed-excitation_2018', 'golabek_construction_2019', 'luc_jonveaux_un0rick_2019', 'qiu_ultrasound_2020', 'lay_progress_2016', 'jonveaux_arduino-like_2017', 'rabani_design_2016', 'xu_high-frequency_2008'], 'max14808': ['rodriguez-olivares_improvement_2018', 'bharath_compact_2018', 'shahshahani_ultrasound_2018', 'pashaei_flexible_2020', 'bharath_novel_2016', 'cowell_-situ_2017', 'dusa_low_2014', 'kidav_architecture_2019', 'lee_new_2014', 'jonveaux_arduino-like_2017'], 'max4936': ['techavipoo_ultrasound_2012'], 'ad9671': [], 'max2077': ['weng_fpga-based_2015'], 'nmt0572sc': ['rabani_design_2016'], 'ad9276': ['li_new_2014', 'techavipoo_ultrasound_2012', 'pashaei_flexible_2020', 'shomaji_early_2019', 'roman_open-source_2019', 'roman_open-source_2018'], 'ad8334': ['shahshahani_ultrasound_2018', 'hu_development_2011'], 'ad9272': ['raj_programmable_2018', 'raj_microcontroller_2017', 'cheung_multi-channel_2012', 'alqasemi_fpga-based_2012', 'batbayar_hardware_2018', 'raj_8051_2016'], 'lm96570': ['bharath_fpga-based_2015', 'bharath_fpga-based_2015', 'bharath_compact_2018', 'gwirc_desarrollo_2019', 'shomaji_early_2019', 'hager_lightprobe:_2017', 'vasudevan_programmable_2014', 'roman_open-source_2019', 'dusa_low_2014', 'hager_design_2019', 'govindan_reconfigurable_2015', 'roman_open-source_2018', 'LP1', 'hager_lightprobe:_2019'], 'md0100': ['li_new_2014', 'sharma_development_2015'], 'hv7361': ['sharma_development_2015'], 'max2084': [], 'lm96530': ['gwirc_desarrollo_2019', 'shomaji_early_2019', 'vasudevan_programmable_2014', 'roman_open-source_2019', 'govindan_reconfigurable_2015', 'roman_open-source_2018'], 'afe5808': ['yu_low-power_2012', 'bharath_fpga-based_2015', 'bharath_fpga-based_2015', 'pandey_open_2019', 'bharath_novel_2016', 'lee_new_2014', 'jonveaux_arduino-like_2017'], 'ad8031': ['svilainis_electronics_2014'], 'ice40hx4k': ['luc_jonveaux_un0rick_2019'], 'tc6320': ['weibao_qiu_programmable_2011', 'sharma_development_2015', 'xu_low-cost_2007', 'qiu_high-resolution_2020', 'wang_high_2019', 'qiu_delayed-excitation_2018', 'levesque_real-time_2009', 'wang_development_2017', 'luc_jonveaux_un0rick_2019', 'qiu_flexible_2012', 'qiu_ultrasound_2020', 'wu_novel_2013'], 'lecoeur': ['yu_low-power_2012', 'csany_real-time_2019-1', 'xu_enabling_2019', 'tortoli_ula-op:_2009', 'zhang_toward_2018', 'fontes-pereira_monitoring ...

# %%
result["lecoeur"]
# Out:
# ['yu_low-power_2012',
#  'csany_real-time_2019-1',
#  'xu_enabling_2019',
#  'tortoli_ula-op:_2009',
#  'zhang_toward_2018',
#  'fontes-pereira_monitoring_2018',
#  'wagner_validity_2016']

# %%
import csv
with open('devices.csv', 'w') as f:
    for key in sorted(result.keys()):
        f.write("%s,%s"%(key,",".join(result[key])))

# %%
for key in sorted(result.keys()):
    print("%s,%d,%s"%(key,len(result[key]),";".join(result[key])))
# Out:
# ad8031,1,svilainis_electronics_2014
# ad8331,11,lorenzo_experimental_2009;pandey_open_2019;qiu_high-resolution_2020;qiu_delayed-excitation_2018;golabek_construction_2019;luc_jonveaux_un0rick_2019;qiu_ultrasound_2020;lay_progress_2016;jonveaux_arduino-like_2017;rabani_design_2016;xu_high-frequency_2008
# ad8332,7,zhang_multi-channel_2017;levesque_real-time_2009;chang-hong_hu_design_2008;brunner_how_2002;2011_PhilippeL%C3%A9vesque;nguyen_estimating_2019;levesque_architecture_2011
# ad8334,2,shahshahani_ultrasound_2018;hu_development_2011
# ad9214,1,svilainis_electronics_2014
# ad9272,6,raj_programmable_2018;raj_microcontroller_2017;cheung_multi-channel_2012;alqasemi_fpga-based_2012;batbayar_hardware_2018;raj_8051_2016
# ad9273,3,hewener_highly_2012;alqasemi_fpga-based_2012;di_ianni_system-level_2016
# ad9276,6,li_new_2014;techavipoo_ultrasound_2012;pashaei_flexible_2020;shomaji_early_2019;roman_open-source_2019;roman_open-source_2018
# ad9671,0,
# ada4807,2,lay_-vivo_2018;lay_progress_2016
# adc10065,1,luc_jonveaux_un0rick_2019
# adc10d020,1,peyton_comparison_2018
# adl5511,1,jonveaux_arduino-like_2017
# ads5517,4,weibao_qiu_programmable_2011;qiu_programmable_2011;qiu_programmable_2010;wang_development_2017
# afe5805,4,assef_flexible_2015;assef_design_2012;assef_compact_2014;assef_initial_2016
# afe5808,7,yu_low-power_2012;bharath_fpga-based_2015;bharath_fpga-based_2015;pandey_open_2019;bharath_novel_2016;lee_new_2014;jonveaux_arduino-like_2017
# afe5809,4,bharath_compact_2018;dusa_low_2014;hager_design_2019;kidav_architecture_2019
# afe5851,5,gwirc_desarrollo_2019;hager_lightprobe:_2017;hager_design_2019;LP1;hager_lightprobe:_2019
# hv7321,0,
# hv7350,7,weng_fpga-based_2015;IUS2017-LightProbe-final-2;hager_lightprobe:_2017;hager_design_2019;LP1;hager_lightprobe:_2019;hager_ultralight:_2017
# hv7360,1,jonveaux_arduino-like_2017
# hv7361,1,sharma_development_2015
# hv9150,0,
# ice40hx4k,1,luc_jonveaux_un0rick_2019
# lecoeur,7,yu_low-power_2012;csany_real-time_2019-1;xu_enabling_2019;tortoli_ula-op:_2009;zhang_toward_2018;fontes-pereira_monitoring_2018;wagner_validity_2016
# lm96511,1,yu_low-power_2012
# lm96530,6,gwirc_desarrollo_2019;shomaji_early_2019;vasudevan_programmable_2014;roman_open-source_2019;govindan_reconfigurable_2015;roman_open-source_2018
# lm96550,2,gwirc_desarrollo_2019;vasudevan_programmable_2014
# lm96551,6,shomaji_early_2019;hager_lightprobe:_2017;roman_open-source_2019;hager_design_2019;govindan_reconfigurable_2015;roman_open-source_2018
# lm96570,14,bharath_fpga-based_2015;bharath_fpga-based_2015;bharath_compact_2018;gwirc_desarrollo_2019;shomaji_early_2019;hager_lightprobe:_2017;vasudevan_programmable_2014;roman_open-source_2019;dusa_low_2014;hager_design_2019;govindan_reconfigurable_2015;roman_open-source_2018;LP1;hager_lightprobe:_2019
# lt3958,1,wang_development_2017
# max1438,2,wall_high-_2010;wall_high-speed_2010
# max14808,10,rodriguez-olivares_improvement_2018;bharath_compact_2018;shahshahani_ultrasound_2018;pashaei_flexible_2020;bharath_novel_2016;cowell_-situ_2017;dusa_low_2014;kidav_architecture_2019;lee_new_2014;jonveaux_arduino-like_2017
# max14813,0,
# max14866,1,pashaei_flexible_2020
# max15031,0,
# max1856,0,
# max2077,1,weng_fpga-based_2015
# max2079,0,
# max2082,1,hewener_mobile_2019
# max2084,0,
# max4107,2,xu_high-frequency_2008;ricci_programmable_2006
# max4936,1,techavipoo_ultrasound_2012
# max668,0,
# md0100,2,li_new_2014;sharma_development_2015
# md0101,6,sharma_development_2015;lay_-vivo_2018;hager_design_2019;LP1;hager_lightprobe:_2019;lay_progress_2016
# md1210,6,sharma_development_2015;levesque_real-time_2009;luc_jonveaux_un0rick_2019;2011_PhilippeL%C3%A9vesque;nguyen_estimating_2019;levesque_architecture_2011
# md2131,4,assef_flexible_2015;assef_design_2012;assef_compact_2014;assef_initial_2016
# md2134,0,
# mic3172,0,
# nmt0572sc,1,rabani_design_2016
# sharmistha,1,shahshahani_ultrasound_2018
# sma231,5,weibao_qiu_programmable_2011;qiu_programmable_2011;qiu_high-resolution_2020;qiu_programmable_2010;wang_development_2017
# sthv748,1,joseph_artsenstouch_2015
# tc6320,12,weibao_qiu_programmable_2011;sharma_development_2015;xu_low-cost_2007;qiu_high-resolution_2020;wang_high_2019;qiu_delayed-excitation_2018;levesque_real-time_2009;wang_development_2017;luc_jonveaux_un0rick_2019;qiu_flexible_2012;qiu_ultrasound_2020;wu_novel_2013
# ths4509,6,weibao_qiu_programmable_2011;qiu_programmable_2011;qiu_high-resolution_2020;qiu_programmable_2010;wang_development_2017;qiu_flexible_2012
# tx810,7,cheung_multi-channel_2012;batbayar_hardware_2018;wang_high_2019;hager_lightprobe:_2017;hager_design_2019;LP1;hager_lightprobe:_2019
# vca8500,3,wang_high_2019;vasudevan_programmable_2014;govindan_reconfigurable_2015
# verasonics,28,cheung_multi-channel_2012;peyton_front-end_2017;kim_real-time_2018;wall_high-_2010;herickhoff_low-cost_2018;george_portable_2018;batbayar_hardware_2018;IUS2017-LightProbe-final-2;pashaei_flexible_2020;shomaji_early_2019;hager_lightprobe:_2017;bottenus_feasibility_2016;wall_high-speed_2010;taylor_development_2017;roman_open-source_2019;kang_new_2017;hager_design_2019;kidav_architecture_2019;roman_open-source_2018;boni_ula-op_2016;boni_ultrasound_2018;wang_high-resolution_2019;LP1;hager_lightprobe:_2019;hager_ultralight:_2017;sensors-18-03314-v2;peyton_comparison_2018;assef_initial_2016
