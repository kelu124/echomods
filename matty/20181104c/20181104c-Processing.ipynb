# %% [markdown]
# # `20181104c` - Phantom and probes - Processing

# %%
#!/usr/bin/python
import spidev
import time
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import json
import time
from pyUn0 import *
# %matplotlib inline
import os
from scipy.signal import hilbert, resample
import cv2
# Out:
# Not loading RPi.GPIO as not on RPi

# %%
for MyDataFile in os.listdir("data/"):
    if MyDataFile.endswith(".json"):
        x = us_json()
        x.fPiezo = 5.0
        x.JSONprocessing("data/"+MyDataFile)
        CleanImage = x.mk2DArray()
        S = x.mkSpectrum(CleanImage)
# Out:
# Data acquired
# Data acquired

# %%
5000*1000/128
# Out:
# 39062

# %%
500*128/1000
# Out:
# 64
