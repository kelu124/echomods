# %% [markdown]
# # `20181126a` `20181126b`- Phantom and probes - Processing

# %% [markdown]
# __BEWARE__: using the __MATTY_V1.1b.bin__ bin file for the V1.1 board.

# %%
#!/usr/bin/python
import spidev
import time
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import json
import time
from pyUn0 import *
# %matplotlib inline
import os
from scipy.signal import hilbert, resample
import cv2
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
HVs = []
for MyDataFile in os.listdir("data/"):
    if MyDataFile.endswith(".json"):
            print MyDataFile
            x = us_json()
            x.fPiezo = 5.0
            x.JSONprocessing("data/"+MyDataFile)
            HVs.append ( x.tmp[len(x.tmp)/2:-1] ) 
            plt.plot(x.tmp[len(x.tmp)/2:-1])
            FileName = "images/"+x.experiment["id"]+"-"+str(x.N)+".jpg"
            plt.title(x.experiment["id"]+"-"+str(x.N)+ " - "+str(x.V)+"V")
            plt.savefig(FileName)
            TagImage(FileName,"matty",x.experiment["id"],"graph",x.experiment["description"]+ " at "+ str(x.V)+"V")
            plt.show()
            #CleanImage = x.mk2DArray()
            #S = x.mkSpectrum(CleanImage)
# Out:
# 20181126b-3.json
# Data acquired
# 20181126b-1.json
# Data acquired
# 20181126a-2.json
# Data acquired
# 20181126a-1.json
# Data acquired
# 20181126b-2.json
# Data acquired
# 20181126a-3.json
# Data acquired

# %%
plt.plot(HVs[0][550:650],'r')
plt.plot(HVs[1][550:650],'b')
plt.plot(HVs[2][550:650],'g')
plt.title("v1.0, at 25, 50 and 75V")
ImageFile = "images/v1.1b.jpg"
plt.savefig(ImageFile)
TagImage(ImageFile,"matty",x.experiment["id"],"graph",x.experiment["description"])
plt.show()

# %%
# Out:
# u'25'
