# %% [markdown]
# # `20190103a` - New board tests

# %%
from pyUn0 import *
# Out:
# Not loading RPi.GPIO as not on RPi

# %%
make_clean("./")
# Out:
# ./data/20190103a-1.json
# ./data/20190103a-2.json
# 0

# %%
for MyDataFile in os.listdir("./data/"):
    if MyDataFile.endswith("2.json"):
        y = us_json()
        y.JSONprocessing("./data/"+MyDataFile)
        y.create_fft() #OK
        y.save_npz()
        y.plot_detail(0,35,40) #@todo correct 
        #@todo make a showfirstline method too
        #y.mkSpectrum()
        #y.mk2DArray() #@todo - DeltaAcq issue
        #y.mkImg() #@todo - DeltaAcq issue
        #print y.create_title_text() #@todo - DeltaAcq issue
        print MyDataFile
# Out:
# Data acquired
# Not an image
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-d052131ca7f6> in <module>()
#       5         y.create_fft() #OK
#       6         y.save_npz()
# ----> 7         y.plot_detail(0,35,40)
#       8         #y.mkSpectrum()
#       9         #y.mk2DArray() #@todo - DeltaAcq issue
#
# /home/kelu/ultrasound/echomods/matty/20190103a/pyUn0.py in plot_detail(self, nb_line, Start, Stop)
#     738         plt.tight_layout()
#     739
# --> 740         file_name = "images/detail_"+self.iD+"-"+str(self.N)+"-"
#     741         file_name += str(Start)+"-"+str(Stop)+"-line"+str(nb_line)+".jpg"
#     742         plt.savefig(file_name)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
# ...

# %%
y.parameters
# Out:
# {u'LengthAcq': 200000,
#  u'LengthAcq_Real': 25600,
#  u'PeriodAcq': 2500000,
#  u'PeriodAcq_Real': 250000,
#  u'Pon': 200,
#  u'Pon_Real': 20,
#  u'PulsesDelay': 300,
#  u'PulsesDelay_Real': 30}

# %%
y.N
# Out:
# 1

# %%
len(y.tdac),len(y.t),len(y.tmp)
# Out:
# (1, 9360, 9360)

# %%
y.Registers
# Out:
# {u'16': 75,
#  u'17': 78,
#  u'18': 82,
#  u'19': 86,
#  u'20': 90,
#  u'208': 30,
#  u'21': 93,
#  u'22': 97,
#  u'222': 0,
#  u'224': 20,
#  u'229': 100,
#  u'23': 101,
#  u'230': 0,
#  u'231': 3,
#  u'232': 208,
#  u'233': 144,
#  u'234': 1,
#  u'235': 1,
#  u'237': 3,
#  u'238': 3,
#  u'239': 1,
#  u'24': 105,
#  u'25': 108,
#  u'26': 112,
#  u'27': 116,
#  u'28': 120,
#  u'29': 123,
#  u'30': 127,
#  u'31': 131,
#  u'32': 135,
#  u'33': 138,
#  u'34': 142,
#  u'35': 146,
#  u'36': 150,
#  u'37': 153,
#  u'38': 157,
#  u'39': 161,
#  u'40': 165,
#  u'41': 168,
#  u'42': 172,
#  u'43': 176,
#  u'44': 180,
#  u'45': 183,
#  u'46': 187,
#  u'47': 191,
#  u'48': 195,
#  u'49': 198,
#  u'50': 202,
#  u'51': 206,
#  u'52': 210,
#  u'53': 213,
#  u'54': 217,
#  u'55': 0,
#  u'56': 0}

# %%
1000/128.0
# Out:
# 7.8125
