# %%
import pyUn0 as us

import numpy as np
import matplotlib.pyplot  as plt

from numpy import genfromtxt

try:
    import cPickle as pickle
except ImportError:  # Python 3.x
    import pickle
# Out:
# Not loading RPi.GPIO as not on RPi
# pyexiv2 does not exist on RPi

# %%
x = us.us_json()
d={}

# %%
plt.figure(figsize=(15,5))
for DAC in range(12):
    x.JSONprocessing("20201008a-"+str(12-(DAC))+".json")
    if DAC == 11:
        DAC = "noise"
    else:
        DAC = int(x.tdac[2])
    d[DAC] = x.tmp[0:x.len_line]

    d["t"] = x.t[0:x.len_line]
    plt.plot(d["t"],d[DAC],label=str(DAC),alpha = 0.7)
plt.legend()
plt.title("Un0rick acquisitions")
plt.savefig("acqs_un0rick.jpg")
# Out:
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired
# 35074 17537.0 17536
# Data acquired

# %%
with open('un0rick.pkl', 'wb') as fp:
    pickle.dump(d, fp, protocol=4)

# %%
with open('un0rick.pkl', 'rb') as fp:
    data = pickle.load(fp)

# %%
data.keys()
# Out:
# dict_keys([0, 't', 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 'noise'])
